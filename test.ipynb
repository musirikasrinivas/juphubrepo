# %%
print("hello world")
# Out:
# hello world

# %%
list1 = [1,2,3,4]
list2 = [5,6,7,8]
l = []
for item in zip(list1,list2):
    k = sum(item)
    l.append(k)
print(l)
# Out:
# [6, 8, 10, 12]

# %% [markdown]
# # New instance in GCP
